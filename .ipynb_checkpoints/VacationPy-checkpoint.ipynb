# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_df = pd.read_csv("output_data/cities.csv")
city_df
# Out:
#                       city      lat      long  maxtemp  humidity  cloudiness  \
# 0                Busselton -33.6500  115.3333    51.89        78          91
# 1              Yerbogachën  61.2767  108.0108    54.34        77         100
# 2                Hithadhoo  -0.6000   73.0833    82.06        72         100
# 3                Sistranda  63.7256    8.8340    60.76        70           4
# 4                   Cairns -16.9167  145.7667    73.35        88         100
# ..                     ...      ...       ...      ...       ...         ...
# 557                Yeppoon -23.1333  150.7333    64.18        92           0
# 558             Kermanshah  34.3142   47.0650   104.90         4           0
# 559  Mayor Pablo Lagerenza -19.9309  -60.7718    71.28        41          79
# 560                   Lata  40.1629   -8.3327    94.41        21           0
# 561                  Pilar  -9.5972  -35.9567    78.73        84          80
#
#      windspeed        date
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key = g_key)

# %%
city_location = city_df[["lat", "long"]]
humidity = city_df["humidity"]
map_fig = gmaps.figure()

heat_map_layer = gmaps.heatmap_layer(city_location, weights=humidity, dissipating=False, max_intensity=300, point_radius=5)

map_fig.add_layer(heat_map_layer)
map_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_df = city_df.loc[
    (city_df["maxtemp"] > 70) & (city_df["maxtemp"] < 80) & \
    (city_df["windspeed"] < 10) & (city_df["cloudiness"] == 0)
].dropna()

weather_df
# Out:
#                   city      lat      long  maxtemp  humidity  cloudiness  \
# 5               Shingū  33.7333  135.9833    77.68        91           0
# 6                Kapaa  22.0752 -159.3190    77.32        91           0
# 11             Horsham  51.0640   -0.3272    74.32        35           0
# 56          Vila Velha -20.3297  -40.2925    78.75        68           0
# 78                Nehe  48.4833  124.8333    70.23        72           0
# 131        Gainesville  29.6516  -82.3248    78.08        81           0
# 143             Bethel  41.3712  -73.4140    78.37        85           0
# 146        Grand Gaube -20.0064   57.6608    75.60        59           0
# 185       Oktyabr'skiy  54.4815   53.4710    79.59        42           0
# 221                Bud  39.4470  -86.1758    73.42        98           0
# 266       Khudumelapye -23.8833   24.7500    79.47        11           0
# 268       Saint-Pierre -21.3393   55.4781    76.68        66           0
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = weather_df[["city", "lat", "long"]]
hotel_df["hotel"] = ""
hotel_df
# Out:
# C:\Users\Bob-Laptop\AppData\Local\Temp/ipykernel_14004/335557712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["hotel"] = ""
#                   city      lat      long hotel
# 5               Shingū  33.7333  135.9833
# 6                Kapaa  22.0752 -159.3190
# 11             Horsham  51.0640   -0.3272
# 56          Vila Velha -20.3297  -40.2925
# 78                Nehe  48.4833  124.8333
# 131        Gainesville  29.6516  -82.3248
# 143             Bethel  41.3712  -73.4140
# 146        Grand Gaube -20.0064   57.6608
# 185       Oktyabr'skiy  54.4815   53.4710
# 221                Bud  39.4470  -86.1758
# 266       Khudumelapye -23.8833   24.7500
# 268       Saint-Pierre -21.3393   55.4781
# ...

# %%
#search for hotel
params = {
    "radius":5000,
    "types": "lodging",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    lat = row["lat"]
    long = row["long"]
    
    params["location"] = f"{lat},{long}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    name_address = requests.get(base_url, params=params).json()
    
    try:
        hotel_df.loc[index, "hotel"] = name_address["results"][0]["name"]
    
    except:
        print(f"Error finding hotel in {row['city']}")
        pass

hotel_df
# Out:
# C:\Users\Bob-Laptop\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Error finding hotel in Khudumelapye
#                   city      lat      long  \
# 5               Shingū  33.7333  135.9833
# 6                Kapaa  22.0752 -159.3190
# 11             Horsham  51.0640   -0.3272
# 56          Vila Velha -20.3297  -40.2925
# 78                Nehe  48.4833  124.8333
# 131        Gainesville  29.6516  -82.3248
# 143             Bethel  41.3712  -73.4140
# 146        Grand Gaube -20.0064   57.6608
# 185       Oktyabr'skiy  54.4815   53.4710
# 221                Bud  39.4470  -86.1758
# 266       Khudumelapye -23.8833   24.7500
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{hotel}</dd>
<dt>City</dt><dd>{city}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["lat", "long"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
map_fig.add_layer(marker_layer)

# Display figure
map_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
